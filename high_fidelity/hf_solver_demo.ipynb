# %%
import numpy as np
import matplotlib.pyplot as plt
from hf_solver import hf_solver

# %%
''' 
Initalizes the object
Inputs: (h_bar, mass, ang_freq, q, dx, x_limit, dt, t_final)
'''
sim = hf_solver(1, 1, 1, -5, 0.05, 5, 0.05, 5)

# %%
''' 
Sets the initial state in the form of a guassian wavepacket
Inputs: (x0, sigma, p)
        x0: initial position 
        sigma: width of wave 
        p: momentum
'''
sim.set_initial_state(x0 = 0.5)

# %%
''' 
Sets the hamiltonian matrix and choose wavefunction scheme
Inputs: (type)
        options:
        QHO: Quantum Harmonic Oscillator 
        GP: Gross-Pitaevskii
'''
sim.construct_hamiltonian("QHO")

# %%
'''
Runs the solver
Inputs (snapshot, snapshot_freq)
'''
sim.run_solver(snapshot = True)
# Out:
# \\wsl.localhost\Ubuntu\home\kozera\wavefunction-dimensionality-reduction\high_fidelity\hf_solver.py:99: ComplexWarning: Casting complex values to real discards the imaginary part
#   total_energies[step] = np.dot(np.dot(np.conj(final_state_norm[:]),self.hamiltonian), final_state_norm[:])
# \\wsl.localhost\Ubuntu\home\kozera\wavefunction-dimensionality-reduction\high_fidelity\hf_solver.py:100: ComplexWarning: Casting complex values to real discards the imaginary part
#   total_kinetics[step] = np.dot(np.dot(np.conj(final_state_norm[:]),self.kinetic), final_state_norm[:])
# \\wsl.localhost\Ubuntu\home\kozera\wavefunction-dimensionality-reduction\high_fidelity\hf_solver.py:101: ComplexWarning: Casting complex values to real discards the imaginary part
#   total_potentials[step] = np.dot(np.dot(np.conj(final_state_norm[:]),self.potential), final_state_norm[:])
# \\wsl.localhost\Ubuntu\home\kozera\wavefunction-dimensionality-reduction\high_fidelity\hf_solver.py:118: ComplexWarning: Casting complex values to real discards the imaginary part
#   total_energies[step] = np.dot(np.dot(np.conj(final_state_norm[:]),self.hamiltonian), final_state_norm[:])
# \\wsl.localhost\Ubuntu\home\kozera\wavefunction-dimensionality-reduction\high_fidelity\hf_solver.py:119: ComplexWarning: Casting complex values to real discards the imaginary part
#   total_kinetics[step] = np.dot(np.dot(np.conj(final_state_norm[:]),self.kinetic), final_state_norm[:])
# \\wsl.localhost\Ubuntu\home\kozera\wavefunction-dimensionality-reduction\high_fidelity\hf_solver.py:120: ComplexWarning: Casting complex values to real discards the imaginary part
#   total_potentials[step] = np.dot(np.dot(np.conj(final_state_norm[:]),self.potential), final_state_norm[:])
# Time taken: 9.20369029045105 sec

# %%
'''
Visualize the wavefunction
Inputs: show: shows the movie in the iPython display 
        save: saves the movie locally as a MP4 
        fps: adjusts the frames per second on the MP4, default is 30)
'''
sim.animation(show = True, save = False)

# %%
'''
Graphs the kinetic, potential, and total energy
'''
sim.graph_energy()

# %%
'''
Graphs the particle count
'''
sim.graph_particle_num()
