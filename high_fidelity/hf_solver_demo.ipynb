# %%
import numpy as np
from hf_solver import hf_solver

# %%
# Initalizes the object
#  (h_bar, mass, ang_freq, q, dx, x_limit, dt, t_final)
sim = hf_solver(1, 1, 1, -5, 0.05, 5, 0.05, 5)

domain, timeframe = sim.get_ranges()

# Sets the initial state
sim.set_initial_state(x0 = 0.5)

# Sets the hamiltonian matrix and choose wavefunction scheme
# QHO: Quantum Harmonic Oscillator; GP: Gross-Pitaevskii
sim.construct_hamiltonian("GP")

# Runs the animation
sim.run_solver()
# Out:
# \\wsl.localhost\Ubuntu\home\kozera\wavefunction-dimensionality-reduction\high_fidelity\hf_solver.py:109: ComplexWarning: Casting complex values to real discards the imaginary part
#   total_energies[step] = np.dot(np.dot(np.conj(final_state_norm[:]),self.hamiltonian), final_state_norm[:])
# \\wsl.localhost\Ubuntu\home\kozera\wavefunction-dimensionality-reduction\high_fidelity\hf_solver.py:110: ComplexWarning: Casting complex values to real discards the imaginary part
#   total_kinetics[step] = np.dot(np.dot(np.conj(final_state_norm[:]),self.kinetic), final_state_norm[:])
# \\wsl.localhost\Ubuntu\home\kozera\wavefunction-dimensionality-reduction\high_fidelity\hf_solver.py:111: ComplexWarning: Casting complex values to real discards the imaginary part
#   total_potentials[step] = np.dot(np.dot(np.conj(final_state_norm[:]),self.potential), final_state_norm[:])
# \\wsl.localhost\Ubuntu\home\kozera\wavefunction-dimensionality-reduction\high_fidelity\hf_solver.py:128: ComplexWarning: Casting complex values to real discards the imaginary part
#   total_energies[step] = np.dot(np.dot(np.conj(final_state_norm[:]),self.hamiltonian), final_state_norm[:])
# \\wsl.localhost\Ubuntu\home\kozera\wavefunction-dimensionality-reduction\high_fidelity\hf_solver.py:129: ComplexWarning: Casting complex values to real discards the imaginary part
#   total_kinetics[step] = np.dot(np.dot(np.conj(final_state_norm[:]),self.kinetic), final_state_norm[:])
# \\wsl.localhost\Ubuntu\home\kozera\wavefunction-dimensionality-reduction\high_fidelity\hf_solver.py:130: ComplexWarning: Casting complex values to real discards the imaginary part
#   total_potentials[step] = np.dot(np.dot(np.conj(final_state_norm[:]),self.potential), final_state_norm[:])
# Time taken: 7.5342066287994385 sec

# %%
sim.animation(show = True, save = True)
# Out:
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (1000, 500) to (1008, 512) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).

# %%
all_states = sim.get_all_states()
print(all_states)
# Out:
# [[[ 2.03281077e-07+0.00000000e+00j  2.67657707e-07+0.00000000e+00j
#     3.51532820e-07+0.00000000e+00j ...  4.71835487e-05+0.00000000e+00j
#     3.77770742e-05+0.00000000e+00j  3.01695868e-05+0.00000000e+00j]
#   [ 2.03281077e-07+0.00000000e+00j  2.67657707e-07+0.00000000e+00j
#     3.51532820e-07+0.00000000e+00j ...  4.71835487e-05+0.00000000e+00j
#     3.77770742e-05+0.00000000e+00j  3.01695868e-05+0.00000000e+00j]
#   [ 2.03281077e-07+0.00000000e+00j  2.67657707e-07+0.00000000e+00j
#     3.51532820e-07+0.00000000e+00j ...  4.71835487e-05+0.00000000e+00j
#     3.77770742e-05+0.00000000e+00j  3.01695868e-05+0.00000000e+00j]
#   ...
#   [ 2.03281077e-07+0.00000000e+00j  2.67657707e-07+0.00000000e+00j
#     3.51532820e-07+0.00000000e+00j ...  4.71835487e-05+0.00000000e+00j
#     3.70386176e-05-1.49184759e-05j ... -6.68889018e-06+1.57937897e-05j
#    -5.74654819e-06+1.00157578e-05j -3.43244235e-06+4.69632469e-06j]
#   [ 9.02346530e-06-1.03774164e-06j  2.16567782e-05-6.14402449e-06j
#     3.70386176e-05-1.49184759e-05j ... -6.68889018e-06+1.57937897e-05j
#    -5.74654819e-06+1.00157578e-05j -3.43244235e-06+4.69632469e-06j]]
#
#  [[ 8.89513073e-06-2.77136358e-06j  2.10831372e-05-9.78651115e-06j
#     3.56959483e-05-2.05313566e-05j ... -4.72502414e-06+1.63324710e-05j
#    -4.30524471e-06+1.07362819e-05j -2.64829934e-06+5.22686636e-06j]
#   [ 8.89513073e-06-2.77136358e-06j  2.10831372e-05-9.78651115e-06j
#     3.56959483e-05-2.05313566e-05j ... -4.72502414e-06+1.63324710e-05j
#    -4.30524471e-06+1.07362819e-05j -2.64829934e-06+5.22686636e-06j]
#   [ 8.89513073e-06-2.77136358e-06j  2.10831372e-05-9.78651115e-06j
#     3.56959483e-05-2.05313566e-05j ... -4.72502414e-06+1.63324710e-05j
#    -4.30524471e-06+1.07362819e-05j -2.64829934e-06+5.22686636e-06j]
#   ...
#   [ 8.89513073e-06-2.77136358e-06j  2.10831372e-05-9.78651115e-06j
#     3.56959483e-05-2.05313566e-05j ... -4.72502414e-06+1.63324710e-05j
#    -4.30524471e-06+1.07362819e-05j -2.64829934e-06+5.22686636e-06j]
#   [ 8.89513073e-06-2.77136358e-06j  2.10831372e-05-9.78651115e-06j
#     3.56959483e-05-2.05313566e-05j ... -4.72502414e-06+1.63324710e-05j
#    -4.30524471e-06+1.07362819e-05j -2.64829934e-06+5.22686636e-06j]
#   [ 8.89513073e-06-2.77136358e-06j  2.10831372e-05-9.78651115e-06j
#     3.56959483e-05-2.05313566e-05j ... -4.72502414e-06+1.63324710e-05j
#    -4.30524471e-06+1.07362819e-05j -2.64829934e-06+5.22686636e-06j]]]

# %%
# Energy can be graphed after the animation or training simulation
sim.graph_energy()

# %%
sim.graph_particle_num()

# %%
initial_state = (1 / np.sqrt(2 * np.pi)) * np.exp(-0.5 * domain**2)
sim.set_initial_state(initial_state)

sim.construct_hamiltonian("QHO")

# Runs the animation
sim.run_animation()

# %%
sim.graph_energy()

# %%
# Basic example of the run_simulation method, this particular instance will record data for the first 100 timesteps. Outputs are the final state, all saved states, all saved energies, and the total time taken.
# Initalizes the object
#  (h_bar, mass, ang_freq, dx, x_limit, dt, t_final)
sim = hf_solver(1, 1, 1, 0.05, 5, 0.01, 5)

# Sets the potential (currently hardcoded to quantum harmonic oscillator)
domain, timeframe = sim.get_ranges()

# Sets the initial state, in this case a guassian wave packet centered at zero. This will eventually all be done strictly through methods.
#initial_state_ = (1 / np.sqrt(2 * np.pi)) * np.exp(-0.5 * domain**2)
initial_state = (1 / np.sqrt(2 * np.pi)) * np.exp(-0.5 * domain**2)
sim.set_initial_state(initial_state)

# Sets the hamiltonian matrix
sim.construct_hamiltonian("GP")

# Runs the animation

f_state, a_states, energies, total_time = sim.run_simulation(100)
print(total_time, 'sec',
      a_states)

# %%
sim.graph_energy()
